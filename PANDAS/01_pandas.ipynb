# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
data = {
    "Name": ["Yash", "Amit", "Neha"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 88]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  Marks
# 0  Yash   21     85
# 1  Amit   22     90
# 2  Neha   20     88
