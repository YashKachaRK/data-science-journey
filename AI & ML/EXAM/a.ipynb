# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('Z:\DS\EXAM\matches.csv')
df.head()
df.tail()
# Convert numeric columns safely
df['wb_runs'] = pd.to_numeric(df['wb_runs'], errors='coerce')
df['first_ings_score'] = pd.to_numeric(df['first_ings_score'], errors='coerce')
df['second_ings_score'] = pd.to_numeric(df['second_ings_score'], errors='coerce')

# ----------------------------------------
# 1️⃣ Wins by Each Team (Bar Chart)
# ----------------------------------------
plt.figure(figsize=(10,5))
df['match_winner'].value_counts().plot(kind='bar')
plt.title("Wins by Each Team")
plt.xlabel("Team")
plt.ylabel("Number of Wins")
plt.xticks(rotation=45)
plt.show()

# ----------------------------------------
# 2️⃣ Toss Decision Distribution (Pie Chart)
# ----------------------------------------
plt.figure(figsize=(6,6))
df['toss_decision'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Toss Decision: Bat vs Bowl")
plt.ylabel("")
plt.show()

# ----------------------------------------
# 3️⃣ Histogram – First Innings Score
# ----------------------------------------
plt.figure(figsize=(8,5))
plt.hist(df['first_ings_score'].dropna(), bins=10)
plt.title("Distribution of First Innings Scores")
plt.xlabel("First Innings Score")
plt.ylabel("Frequency")
plt.show()

# ----------------------------------------
# 4️⃣ Matches Played per Venue (Bar Chart)
# ----------------------------------------
plt.figure(figsize=(12,5))
df['venue'].value_counts().plot(kind='bar')
plt.title("Matches Played Per Venue")
plt.xlabel("Venue")
plt.ylabel("Match Count")
plt.xticks(rotation=90)
plt.show()

# ----------------------------------------
# 5️⃣ Line Graph – Win By Runs Over Matches
# ----------------------------------------
plt.figure(figsize=(10,4))
plt.plot(df.index, df['wb_runs'].fillna(0))
plt.title("Winning Margin (Runs) Across Matches")
plt.xlabel("Match Index")
plt.ylabel("Win By Runs")
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\yashk\AppData\Local\Temp\ipykernel_8620\2717848138.py:6: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('Z:\DS\EXAM\matches.csv')
# C:\Users\yashk\AppData\Local\Temp\ipykernel_8620\2717848138.py:6: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('Z:\DS\EXAM\matches.csv')
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
