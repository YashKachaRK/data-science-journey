# %% [markdown]
# # Execise 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/mobile.csv')

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.tail()
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
puchased_data = df[["Age", "EstimatedSalary", "Purchased"]][df["Purchased"] == 1]
puchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 7     32           150000          1
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# ..   ...              ...        ...
# 393   60            42000          1
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 399   49            36000          1
#
# [143 rows x 3 columns]

# %%
not_puchased_data = df[["Age", "EstimatedSalary", "Purchased"]][df["Purchased"] == 0]
not_puchased_data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 377   42            53000          0
# 380   42            64000          0
# 387   39            71000          0
# 394   39            59000          0
# 398   36            33000          0
#
# [257 rows x 3 columns]

# %%
plt.scatter(puchased_data["Age"], puchased_data["EstimatedSalary"], color='green')
plt.scatter(not_puchased_data["Age"], not_puchased_data["EstimatedSalary"], color='red')

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df['EstimatedSalary'].max()
# Out:
# np.int64(150000)

# %%
df['EstimatedSalary'].min()
# Out:
# np.int64(15000)

# %%
df['Age'].max()
# Out:
# np.int64(60)

# %%
df['Age'].min()
# Out:
# np.int64(18)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_to_scale = ['Age', 'EstimatedSalary']
scaled_values = scaler.fit_transform(df[features_to_scale])

# %%
df["norm_Age"] = scaled_values[:, 0]
df["norm_Salary"] = scaled_values[:, 1]

# %%
df
# Out:
#      Age  EstimatedSalary  Purchased  norm_Age  norm_Salary
# 0     19            19000          0  0.023810     0.029630
# 1     35            20000          0  0.404762     0.037037
# 2     26            43000          0  0.190476     0.207407
# 3     27            57000          0  0.214286     0.311111
# 4     19            76000          0  0.023810     0.451852
# ..   ...              ...        ...       ...          ...
# 395   46            41000          1  0.666667     0.192593
# 396   51            23000          1  0.785714     0.059259
# 397   50            20000          1  0.761905     0.037037
# 398   36            33000          0  0.428571     0.133333
# 399   49            36000          1  0.738095     0.155556
#
# [400 rows x 5 columns]

# %%
df['norm_Age'].min()
# Out:
# np.float64(0.0)

# %%
df['norm_Age'].max()
# Out:
# np.float64(0.9999999999999998)

# %%
df['norm_Salary'].min()
# Out:
# np.float64(0.0)

# %%
df['norm_Salary'].max()
# Out:
# np.float64(1.0)
